# %%
import sys
import pandas as pd
import os
sys.path.append('..')
from settings import *


df = pd.read_csv(STATISTICS_REASON_FILE_MINIMAL)
sum_column = df.iloc[:, 0]
count_column = df.iloc[:, 1]
sum_value = sum_column.sum()
count_value = count_column.sum()

print(f"Mean decreasing for minimal reason: {sum_value / count_value} %")
# Out:
# Mean decreasing for minimal reason: 2.927073062998515 %

# %%
import sys
import pandas as pd
import os
sys.path.append('..')
from settings import *


df = pd.read_csv(STATISTICS_REASON_FILE_MINIMUM)
sum_column = df.iloc[:, 0]
count_column = df.iloc[:, 1]
sum_value = sum_column.sum()
count_value = count_column.sum()

print(f"Mean decreasing for cardinality minimal reason: {sum_value / count_value} %")
# Out:
# Mean decreasing for cardinality minimal reason: 12.481009736061397 %
