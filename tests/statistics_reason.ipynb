# %%
import sys
import pandas as pd
import os
sys.path.append('..')
from settings import *


df = pd.read_csv(STATISTICS_REASON_FILE_MINIMAL)
sum_column = df.iloc[:, 0]
count_column = df.iloc[:, 1]
sum_value = sum_column.sum()
count_value = count_column.sum()

print(f"Mean decreasing for minimal reason: {sum_value / count_value} %")
# Out:
# Mean of the first column: 9.905048743143986 %

# %%
import sys
import pandas as pd
import os
sys.path.append('..')
from settings import *

df = pd.read_csv(STATISTICS_REASON_FILE_MINIMUM)
first_column = df.iloc[:, 0]
mean_value = first_column.mean()

print(f"Mean of the first column: {mean_value} %")
# Out:
# Mean of the first column: 12.286001124096366 %
